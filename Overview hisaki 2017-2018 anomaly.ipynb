# %%
# import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

year = 2017

# Read CSV
file_path = '/media/user/Data/Timeline/Data_table/'+ f'Datatable_{year}.csv' 
df = pd.read_csv(file_path)

# Lon filter
df = df[(df["Lon"] >= 60) & (df["Lon"] <= 150)]

#load GOES data
dir_e = "/media/user/Data/Timeline/GOES15/Elec/"
dir_p = "/media/user/Data/Timeline/GOES15/Proton/"
dir_x = "/media/user/Data/Timeline/GOES15/Xray/"
dir_m = "/media/user/Data/Timeline/GOES15/Mag/"

npz_e = np.load(dir_e+f"GOES_elec_{year}.npz")
npz_p = np.load(dir_p+f"GOES_proton_{year}.npz")
npz_x = np.load(dir_x+f"GOES_xray_{year}.npz")
npz_m = np.load(dir_m+f"GOES_mag_{year}.npz")

#print(df_e)
#Load SYM-H data
dir_s = "/media/user/Data/Timeline/ae_index/"
df_s = pd.read_csv(dir_s+f"SYM-H_1min_{year}.csv")

# Contents of npz => ['Time', 'DOY', 'year', 'flux']
df_e = pd.DataFrame({
    "Time": npz_e["Time"],
    "DOY":  npz_e["DOY"],
    "year": npz_e["year"],
    "flux": npz_e["flux"],
})

df_p = pd.DataFrame({
    "Time": npz_p["Time"],
    "DOY":  npz_p["DOY"],
    "year": npz_p["year"],
    "flux": npz_p["flux"],
})

df_x = pd.DataFrame({
    "Time": npz_x["Time"],
    "DOY":  npz_x["DOY"],
    "year": npz_x["year"],
    "flux": npz_x["flux"],
})

df_m = pd.DataFrame({
    "Time": npz_m["Time"],
    "DOY":  npz_m["DOY"],
    "year": npz_m["year"],
    "flux": npz_m["flux"],
})

# %%
print(data_e.files)
# Out:
# ['Time', 'DOY', 'year', 'flux']

# %%
df_s.head()
# Out:
#               Datetime       DOY  SYM-H
# 0  2017-01-01 00:00:00  1.000000  -18.0
# 1  2017-01-01 00:01:00  1.000694  -18.0
# 2  2017-01-01 00:02:00  1.001389  -18.0
# 3  2017-01-01 00:03:00  1.002083  -17.0
# 4  2017-01-01 00:04:00  1.002778  -17.0

# %%
#Plot the dark count and geomagnetic and solar flare index in the same period in 2017
days, daye = 249, 252   

df_his = df[(df["DOY"] >= days) & (df["DOY"] < daye)]
df_s_sub = df_s[(df_s["DOY"] >= days) & (df_s["DOY"] < daye)]
df_x_sub = df_x[(df_x["DOY"] >= days) & (df_x["DOY"] < daye)]
df_e_sub = df_e[(df_e["DOY"] >= days) & (df_e["DOY"] < daye)]
df_p_sub = df_p[(df_p["DOY"] >= days) & (df_p["DOY"] < daye)]
df_m_sub = df_m[(df_m["DOY"] >= days) & (df_m["DOY"] < daye)]


fig, axes = plt.subplots(
    nrows=6, ncols=1,
    figsize=(6, 6),
    sharex=True,
    gridspec_kw={"hspace": 0}  
)


for ax in axes[:-1]:
    ax.tick_params(axis="x", which="both",
                   bottom=False, top=False, labelbottom=False)


axes[0].set_title(f"{year}")
axes[0].scatter(df_his["DOY"], df_his["Count"], s=1.0)
axes[0].set_ylabel("Dark count")

axes[1].plot(df_s_sub["DOY"], df_s_sub["SYM-H"], color='red')  
axes[1].set_ylabel("SYM-H \n[nT]")

axes[5].plot(df_x_sub["DOY"], df_x_sub["flux"], color='red')
axes[5].set_ylabel("X-ray \n[W/$m^{2}$]")

axes[2].plot(df_e_sub["DOY"], df_e_sub["flux"], color='red')
axes[2].set_ylabel("Electron \n[cm$^2$ s sr]")

axes[3].plot(df_p_sub["DOY"], df_p_sub["flux"], color='red')
axes[3].set_ylabel("Proton \n[cm$^2$ s sr]")

axes[4].plot(df_m_sub["DOY"], df_m_sub["flux"], color='red')
axes[4].set_ylabel("Mag \n[nT]")
axes[5].set_xlabel("Day of Year")

for i in [2,3,5]:
    axes[i].set_yscale("log")

for i in range(6):
    axes[i].set_xlim([days,daye])
    
fig.tight_layout()
plt.savefig(f"anomaly_{year}.png",dpi=600)
plt.show()

# %%
# import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

year = 2018

# Read CSV
file_path = '/media/user/Data/Timeline/Data_table/'+ f'Datatable_{year}.csv' 
df = pd.read_csv(file_path)

# Lon filter
df = df[(df["Lon"] >= 60) & (df["Lon"] <= 150)]

#load GOES data
dir_e = "/media/user/Data/Timeline/GOES15/Elec/"
dir_p = "/media/user/Data/Timeline/GOES15/Proton/"
dir_x = "/media/user/Data/Timeline/GOES15/Xray/"
dir_m = "/media/user/Data/Timeline/GOES15/Mag/"

npz_e = np.load(dir_e+f"GOES_elec_{year}.npz")
npz_p = np.load(dir_p+f"GOES_proton_{year}.npz")
npz_x = np.load(dir_x+f"GOES_xray_{year}.npz")
npz_m = np.load(dir_m+f"GOES_mag_{year}.npz")

#print(df_e)
#Load SYM-H data
dir_s = "/media/user/Data/Timeline/ae_index/"
df_s = pd.read_csv(dir_s+f"SYM-H_1min_{year}.csv")

# contents of npz => ['Time', 'DOY', 'year', 'flux']
df_e = pd.DataFrame({
    "Time": npz_e["Time"],
    "DOY":  npz_e["DOY"],
    "year": npz_e["year"],
    "flux": npz_e["flux"],
})

df_p = pd.DataFrame({
    "Time": npz_p["Time"],
    "DOY":  npz_p["DOY"],
    "year": npz_p["year"],
    "flux": npz_p["flux"],
})

df_x = pd.DataFrame({
    "Time": npz_x["Time"],
    "DOY":  npz_x["DOY"],
    "year": npz_x["year"],
    "flux": npz_x["flux"],
})

df_m = pd.DataFrame({
    "Time": npz_m["Time"],
    "DOY":  npz_m["DOY"],
    "year": npz_m["year"],
    "flux": npz_m["flux"],
})

# %%
#Plot the dark count and geomagnetic and solar flare index in the same period in 2018
days, daye = 236, 239   

df_his = df[(df["DOY"] >= days) & (df["DOY"] < daye)]
df_s_sub = df_s[(df_s["DOY"] >= days) & (df_s["DOY"] < daye)]
df_x_sub = df_x[(df_x["DOY"] >= days) & (df_x["DOY"] < daye)]
df_e_sub = df_e[(df_e["DOY"] >= days) & (df_e["DOY"] < daye)]
df_p_sub = df_p[(df_p["DOY"] >= days) & (df_p["DOY"] < daye)]
df_m_sub = df_m[(df_m["DOY"] >= days) & (df_m["DOY"] < daye)]


fig, axes = plt.subplots(
    nrows=6, ncols=1,
    figsize=(6, 6),
    sharex=True,
    gridspec_kw={"hspace": 0}  
)


for ax in axes[:-1]:
    ax.tick_params(axis="x", which="both",
                   bottom=False, top=False, labelbottom=False)


axes[0].set_title(f"{year}")
axes[0].scatter(df_his["DOY"], df_his["Count"], s=2)
axes[0].set_ylabel("Dark count")

axes[1].plot(df_s_sub["DOY"], df_s_sub["SYM-H"], color='red')   
axes[1].set_ylabel("SYM-H \n[nT]")

axes[5].plot(df_x_sub["DOY"], df_x_sub["flux"], color='red')
axes[5].set_ylabel("X-ray \n[W/$m^{2}$]")

axes[2].plot(df_e_sub["DOY"], df_e_sub["flux"], color='red')
axes[2].set_ylabel("Electron \n[cm$^2$ s sr]")

axes[3].plot(df_p_sub["DOY"], df_p_sub["flux"], color='red')
axes[3].set_ylabel("Proton \n[cm$^2$ s sr]")

axes[4].plot(df_m_sub["DOY"], df_m_sub["flux"], color='red')
axes[4].set_ylabel("Mag \n[nT]")
axes[5].set_xlabel("Day of Year")

for i in [2,3,5]:
    axes[i].set_yscale("log")

for i in range(6):
    axes[i].set_xlim([days,daye])
    
fig.tight_layout()
plt.savefig(f"anomaly_{year}.png",dpi=600)
plt.show()

# %%
# import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
year = 2015


file_path = '/media/user/Data/Timeline/Data_table/'+ f'Datatable_{year}.csv' 
df = pd.read_csv(file_path)


df = df[(df["Lon"] >= 60) & (df["Lon"] <= 150)]

#load GOES data
dir_e = "/media/user/Data/Timeline/GOES15/Elec/"
dir_p = "/media/user/Data/Timeline/GOES15/Proton/"
dir_x = "/media/user/Data/Timeline/GOES15/Xray/"
dir_m = "/media/user/Data/Timeline/GOES15/Mag/"

npz_e = np.load(dir_e+f"GOES_elec_{year}.npz")
npz_p = np.load(dir_p+f"GOES_proton_{year}.npz")
npz_x = np.load(dir_x+f"GOES_xray_{year}.npz")
npz_m = np.load(dir_m+f"GOES_mag_{year}.npz")

#print(df_e)
#Load SYM-H data
dir_s = "/media/user/Data/Timeline/ae_index/"
df_s = pd.read_csv(dir_s+f"SYM-H_1min_{year}.csv")


df_e = pd.DataFrame({
    "Time": npz_e["Time"],
    "DOY":  npz_e["DOY"],
    "year": npz_e["year"],
    "flux": npz_e["flux"],
})

df_p = pd.DataFrame({
    "Time": npz_p["Time"],
    "DOY":  npz_p["DOY"],
    "year": npz_p["year"],
    "flux": npz_p["flux"],
})

df_x = pd.DataFrame({
    "Time": npz_x["Time"],
    "DOY":  npz_x["DOY"],
    "year": npz_x["year"],
    "flux": npz_x["flux"],
})

df_m = pd.DataFrame({
    "Time": npz_m["Time"],
    "DOY":  npz_m["DOY"],
    "year": npz_m["year"],
    "flux": npz_m["flux"],
})

# %%
days, daye = 11, 14   

df_his = df[(df["DOY"] >= days) & (df["DOY"] < daye)]
df_s_sub = df_s[(df_s["DOY"] >= days) & (df_s["DOY"] < daye)]
df_x_sub = df_x[(df_x["DOY"] >= days) & (df_x["DOY"] < daye)]
df_e_sub = df_e[(df_e["DOY"] >= days) & (df_e["DOY"] < daye)]
df_p_sub = df_p[(df_p["DOY"] >= days) & (df_p["DOY"] < daye)]
df_m_sub = df_m[(df_m["DOY"] >= days) & (df_m["DOY"] < daye)]


fig, axes = plt.subplots(
    nrows=6, ncols=1,
    figsize=(5, 6),
    sharex=True,
    gridspec_kw={"hspace": 0}  
)




for ax in axes[:-1]:
    ax.tick_params(axis="x", which="both",
                   bottom=False, top=False, labelbottom=False)


axes[0].set_title(f"{year}")
axes[0].scatter(df_his["DOY"], df_his["Count"], s=2)
axes[0].set_ylabel("Dark count")

axes[1].plot(df_s_sub["DOY"], df_s_sub["SYM-H"], color='red')  
axes[1].set_ylabel("SYM-H \n[nT]")

axes[5].plot(df_x_sub["DOY"], df_x_sub["flux"], color='red')
axes[5].set_ylabel("X-ray \n[W/$m^{2}$]")

axes[2].plot(df_e_sub["DOY"], df_e_sub["flux"], color='red')
axes[2].set_ylabel("Electron \n[cm$^2$ s sr]")

axes[3].plot(df_p_sub["DOY"], df_p_sub["flux"], color='red')
axes[3].set_ylabel("Proton \n[cm$^2$ s sr]")

axes[4].plot(df_m_sub["DOY"], df_m_sub["flux"], color='red')
axes[4].set_ylabel("Mag \n[nT]")
axes[5].set_xlabel("Day of Year")

for i in [2,3,5]:
    axes[i].set_yscale("log")

for i in range(6):
    axes[i].set_xlim([days,daye])
    
fig.tight_layout()
plt.savefig(f"anomaly_{year}_1.png",dpi=600)
plt.show()

# %%
days, daye = 75, 78   

df_his = df[(df["DOY"] >= days) & (df["DOY"] < daye)]
df_s_sub = df_s[(df_s["DOY"] >= days) & (df_s["DOY"] < daye)]
df_x_sub = df_x[(df_x["DOY"] >= days) & (df_x["DOY"] < daye)]
df_e_sub = df_e[(df_e["DOY"] >= days) & (df_e["DOY"] < daye)]
df_p_sub = df_p[(df_p["DOY"] >= days) & (df_p["DOY"] < daye)]
df_m_sub = df_m[(df_m["DOY"] >= days) & (df_m["DOY"] < daye)]


fig, axes = plt.subplots(
    nrows=6, ncols=1,
    figsize=(5, 6),
    sharex=True,
    gridspec_kw={"hspace": 0}  
)




for ax in axes[:-1]:
    ax.tick_params(axis="x", which="both",
                   bottom=False, top=False, labelbottom=False)

# ---- 各パネルのプロット ----
axes[0].set_title(f"{year}")
axes[0].scatter(df_his["DOY"], df_his["Count"], s=2)
axes[0].set_ylabel("Dark count")

axes[1].plot(df_s_sub["DOY"], df_s_sub["SYM-H"], color='red')  
axes[1].set_ylabel("SYM-H \n[nT]")

axes[5].plot(df_x_sub["DOY"], df_x_sub["flux"], color='red')
axes[5].set_ylabel("X-ray \n[W/$m^{2}$]")

axes[2].plot(df_e_sub["DOY"], df_e_sub["flux"], color='red')
axes[2].set_ylabel("Electron \n[cm$^2$ s sr]")

axes[3].plot(df_p_sub["DOY"], df_p_sub["flux"], color='red')
axes[3].set_ylabel("Proton \n[cm$^2$ s sr]")

axes[4].plot(df_m_sub["DOY"], df_m_sub["flux"], color='red')
axes[4].set_ylabel("Mag \n[nT]")
axes[5].set_xlabel("Day of Year")

for i in [2,3,5]:
    axes[i].set_yscale("log")

for i in range(6):
    axes[i].set_xlim([days,daye])
    
fig.tight_layout()
plt.savefig(f"anomaly_{year}_2.png",dpi=600)
plt.show()

# %%
days, daye = 172, 175   

df_his = df[(df["DOY"] >= days) & (df["DOY"] < daye)]
df_s_sub = df_s[(df_s["DOY"] >= days) & (df_s["DOY"] < daye)]
df_x_sub = df_x[(df_x["DOY"] >= days) & (df_x["DOY"] < daye)]
df_e_sub = df_e[(df_e["DOY"] >= days) & (df_e["DOY"] < daye)]
df_p_sub = df_p[(df_p["DOY"] >= days) & (df_p["DOY"] < daye)]
df_m_sub = df_m[(df_m["DOY"] >= days) & (df_m["DOY"] < daye)]


fig, axes = plt.subplots(
    nrows=6, ncols=1,
    figsize=(5, 6),
    sharex=True,
    gridspec_kw={"hspace": 0} 
)



for ax in axes[:-1]:
    ax.tick_params(axis="x", which="both",
                   bottom=False, top=False, labelbottom=False)

axes[0].set_title(f"{year}")
axes[0].scatter(df_his["DOY"], df_his["Count"], s=2)
axes[0].set_ylabel("Dark count")

axes[1].plot(df_s_sub["DOY"], df_s_sub["SYM-H"], color='red')   
axes[1].set_ylabel("SYM-H \n[nT]")

axes[5].plot(df_x_sub["DOY"], df_x_sub["flux"], color='red')
axes[5].set_ylabel("X-ray \n[W/$m^{2}$]")

axes[2].plot(df_e_sub["DOY"], df_e_sub["flux"], color='red')
axes[2].set_ylabel("Electron \n[cm$^2$ s sr]")

axes[3].plot(df_p_sub["DOY"], df_p_sub["flux"], color='red')
axes[3].set_ylabel("Proton \n[cm$^2$ s sr]")

axes[4].plot(df_m_sub["DOY"], df_m_sub["flux"], color='red')
axes[4].set_ylabel("Mag \n[nT]")
axes[5].set_xlabel("Day of Year")

for i in [2,3,5]:
    axes[i].set_yscale("log")

for i in range(6):
    axes[i].set_xlim([days,daye])
    
fig.tight_layout()
plt.savefig(f"anomaly_{year}_3.png",dpi=600)
plt.show()

# %%
days, daye = 238, 241   

df_his = df[(df["DOY"] >= days) & (df["DOY"] < daye)]
df_s_sub = df_s[(df_s["DOY"] >= days) & (df_s["DOY"] < daye)]
df_x_sub = df_x[(df_x["DOY"] >= days) & (df_x["DOY"] < daye)]
df_e_sub = df_e[(df_e["DOY"] >= days) & (df_e["DOY"] < daye)]
df_p_sub = df_p[(df_p["DOY"] >= days) & (df_p["DOY"] < daye)]
df_m_sub = df_m[(df_m["DOY"] >= days) & (df_m["DOY"] < daye)]

fig, axes = plt.subplots(
    nrows=6, ncols=1,
    figsize=(5, 6),
    sharex=True,
    gridspec_kw={"hspace": 0}  
)




for ax in axes[:-1]:
    ax.tick_params(axis="x", which="both",
                   bottom=False, top=False, labelbottom=False)


axes[0].set_title(f"{year}")
axes[0].scatter(df_his["DOY"], df_his["Count"], s=2)
axes[0].set_ylabel("Dark count")

axes[1].plot(df_s_sub["DOY"], df_s_sub["SYM-H"], color='red')   
axes[1].set_ylabel("SYM-H \n[nT]")

axes[5].plot(df_x_sub["DOY"], df_x_sub["flux"], color='red')
axes[5].set_ylabel("X-ray \n[W/$m^{2}$]")

axes[2].plot(df_e_sub["DOY"], df_e_sub["flux"], color='red')
axes[2].set_ylabel("Electron \n[cm$^2$ s sr]")

axes[3].plot(df_p_sub["DOY"], df_p_sub["flux"], color='red')
axes[3].set_ylabel("Proton \n[cm$^2$ s sr]")

axes[4].plot(df_m_sub["DOY"], df_m_sub["flux"], color='red')
axes[4].set_ylabel("Mag \n[nT]")
axes[5].set_xlabel("Day of Year")

for i in [2,3,5]:
    axes[i].set_yscale("log")

for i in range(6):
    axes[i].set_xlim([days,daye])
    
fig.tight_layout()
plt.savefig(f"anomaly_{year}_4.png",dpi=600)
plt.show()

# %%
days, daye = 278, 281   

df_his = df[(df["DOY"] >= days) & (df["DOY"] < daye)]
df_s_sub = df_s[(df_s["DOY"] >= days) & (df_s["DOY"] < daye)]
df_x_sub = df_x[(df_x["DOY"] >= days) & (df_x["DOY"] < daye)]
df_e_sub = df_e[(df_e["DOY"] >= days) & (df_e["DOY"] < daye)]
df_p_sub = df_p[(df_p["DOY"] >= days) & (df_p["DOY"] < daye)]
df_m_sub = df_m[(df_m["DOY"] >= days) & (df_m["DOY"] < daye)]


fig, axes = plt.subplots(
    nrows=6, ncols=1,
    figsize=(5, 6),
    sharex=True,
    gridspec_kw={"hspace": 0}  
)




for ax in axes[:-1]:
    ax.tick_params(axis="x", which="both",
                   bottom=False, top=False, labelbottom=False)


axes[0].set_title(f"{year}")
axes[0].scatter(df_his["DOY"], df_his["Count"], s=2)
axes[0].set_ylabel("Dark count")

axes[1].plot(df_s_sub["DOY"], df_s_sub["SYM-H"], color='red')   
axes[1].set_ylabel("SYM-H \n[nT]")

axes[5].plot(df_x_sub["DOY"], df_x_sub["flux"], color='red')
axes[5].set_ylabel("X-ray \n[W/$m^{2}$]")

axes[2].plot(df_e_sub["DOY"], df_e_sub["flux"], color='red')
axes[2].set_ylabel("Electron \n[cm$^2$ s sr]")

axes[3].plot(df_p_sub["DOY"], df_p_sub["flux"], color='red')
axes[3].set_ylabel("Proton \n[cm$^2$ s sr]")

axes[4].plot(df_m_sub["DOY"], df_m_sub["flux"], color='red')
axes[4].set_ylabel("Mag \n[nT]")
axes[5].set_xlabel("Day of Year")

for i in [2,3,5]:
    axes[i].set_yscale("log")

for i in range(6):
    axes[i].set_xlim([days,daye])
    
fig.tight_layout()
plt.savefig(f"anomaly_{year}_5.png",dpi=600)
plt.show()

# %%
# import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
year = 2016


file_path = '/media/user/Data/Timeline/Data_table/'+ f'Datatable_{year}.csv' 
df = pd.read_csv(file_path)


df = df[(df["Lon"] >= 60) & (df["Lon"] <= 150)]

#load GOES data
dir_e = "/media/user/Data/Timeline/GOES15/Elec/"
dir_p = "/media/user/Data/Timeline/GOES15/Proton/"
dir_x = "/media/user/Data/Timeline/GOES15/Xray/"
dir_m = "/media/user/Data/Timeline/GOES15/Mag/"

npz_e = np.load(dir_e+f"GOES_elec_{year}.npz")
npz_p = np.load(dir_p+f"GOES_proton_{year}.npz")
npz_x = np.load(dir_x+f"GOES_xray_{year}.npz")
npz_m = np.load(dir_m+f"GOES_mag_{year}.npz")

#print(df_e)
#Load SYM-H data
dir_s = "/media/user/Data/Timeline/ae_index/"
df_s = pd.read_csv(dir_s+f"SYM-H_1min_{year}.csv")


df_e = pd.DataFrame({
    "Time": npz_e["Time"],
    "DOY":  npz_e["DOY"],
    "year": npz_e["year"],
    "flux": npz_e["flux"],
})

df_p = pd.DataFrame({
    "Time": npz_p["Time"],
    "DOY":  npz_p["DOY"],
    "year": npz_p["year"],
    "flux": npz_p["flux"],
})

df_x = pd.DataFrame({
    "Time": npz_x["Time"],
    "DOY":  npz_x["DOY"],
    "year": npz_x["year"],
    "flux": npz_x["flux"],
})

df_m = pd.DataFrame({
    "Time": npz_m["Time"],
    "DOY":  npz_m["DOY"],
    "year": npz_m["year"],
    "flux": npz_m["flux"],
})

# %%
days, daye = 51, 54   

df_his = df[(df["DOY"] >= days) & (df["DOY"] < daye)]
df_s_sub = df_s[(df_s["DOY"] >= days) & (df_s["DOY"] < daye)]
df_x_sub = df_x[(df_x["DOY"] >= days) & (df_x["DOY"] < daye)]
df_e_sub = df_e[(df_e["DOY"] >= days) & (df_e["DOY"] < daye)]
df_p_sub = df_p[(df_p["DOY"] >= days) & (df_p["DOY"] < daye)]
df_m_sub = df_m[(df_m["DOY"] >= days) & (df_m["DOY"] < daye)]

fig, axes = plt.subplots(
    nrows=6, ncols=1,
    figsize=(5, 6),
    sharex=True,
    gridspec_kw={"hspace": 0}  
)




for ax in axes[:-1]:
    ax.tick_params(axis="x", which="both",
                   bottom=False, top=False, labelbottom=False)


axes[0].set_title(f"{year}")
axes[0].scatter(df_his["DOY"], df_his["Count"], s=2)
axes[0].set_ylabel("Dark count")

axes[1].plot(df_s_sub["DOY"], df_s_sub["SYM-H"], color='red')   
axes[1].set_ylabel("SYM-H \n[nT]")

axes[5].plot(df_x_sub["DOY"], df_x_sub["flux"], color='red')
axes[5].set_ylabel("X-ray \n[W/$m^{2}$]")

axes[2].plot(df_e_sub["DOY"], df_e_sub["flux"], color='red')
axes[2].set_ylabel("Electron \n[cm$^2$ s sr]")

axes[3].plot(df_p_sub["DOY"], df_p_sub["flux"], color='red')
axes[3].set_ylabel("Proton \n[cm$^2$ s sr]")

axes[4].plot(df_m_sub["DOY"], df_m_sub["flux"], color='red')
axes[4].set_ylabel("Mag \n[nT]")
axes[5].set_xlabel("Day of Year")

for i in [2,3,5]:
    axes[i].set_yscale("log")

for i in range(6):
    axes[i].set_xlim([days,daye])
    
fig.tight_layout()
plt.savefig(f"anomaly_{year}.png",dpi=600)
plt.show()

# %%
# import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
year = 2018


file_path = '/media/user/Data/Timeline/Data_table/'+ f'Datatable_{year}.csv' 
df = pd.read_csv(file_path)


df = df[(df["Lon"] >= 60) & (df["Lon"] <= 150)]

#load GOES data
dir_e = "/media/user/Data/Timeline/GOES15/Elec/"
dir_p = "/media/user/Data/Timeline/GOES15/Proton/"
dir_x = "/media/user/Data/Timeline/GOES15/Xray/"
dir_m = "/media/user/Data/Timeline/GOES15/Mag/"

npz_e = np.load(dir_e+f"GOES_elec_{year}.npz")
npz_p = np.load(dir_p+f"GOES_proton_{year}.npz")
npz_x = np.load(dir_x+f"GOES_xray_{year}.npz")
npz_m = np.load(dir_m+f"GOES_mag_{year}.npz")

#print(df_e)
#Load SYM-H data
dir_s = "/media/user/Data/Timeline/ae_index/"
df_s = pd.read_csv(dir_s+f"SYM-H_1min_{year}.csv")


df_e = pd.DataFrame({
    "Time": npz_e["Time"],
    "DOY":  npz_e["DOY"],
    "year": npz_e["year"],
    "flux": npz_e["flux"],
})

df_p = pd.DataFrame({
    "Time": npz_p["Time"],
    "DOY":  npz_p["DOY"],
    "year": npz_p["year"],
    "flux": npz_p["flux"],
})

df_x = pd.DataFrame({
    "Time": npz_x["Time"],
    "DOY":  npz_x["DOY"],
    "year": npz_x["year"],
    "flux": npz_x["flux"],
})

df_m = pd.DataFrame({
    "Time": npz_m["Time"],
    "DOY":  npz_m["DOY"],
    "year": npz_m["year"],
    "flux": npz_m["flux"],
})

# %%
days, daye = 124, 127   

df_his = df[(df["DOY"] >= days) & (df["DOY"] < daye)]
df_s_sub = df_s[(df_s["DOY"] >= days) & (df_s["DOY"] < daye)]
df_x_sub = df_x[(df_x["DOY"] >= days) & (df_x["DOY"] < daye)]
df_e_sub = df_e[(df_e["DOY"] >= days) & (df_e["DOY"] < daye)]
df_p_sub = df_p[(df_p["DOY"] >= days) & (df_p["DOY"] < daye)]
df_m_sub = df_m[(df_m["DOY"] >= days) & (df_m["DOY"] < daye)]


fig, axes = plt.subplots(
    nrows=6, ncols=1,
    figsize=(5, 6),
    sharex=True,
    gridspec_kw={"hspace": 0}  
)




for ax in axes[:-1]:
    ax.tick_params(axis="x", which="both",
                   bottom=False, top=False, labelbottom=False)


axes[0].set_title(f"{year}")
axes[0].scatter(df_his["DOY"], df_his["Count"], s=2)
axes[0].set_ylabel("Dark count")

axes[1].plot(df_s_sub["DOY"], df_s_sub["SYM-H"], color='red')   
axes[1].set_ylabel("SYM-H \n[nT]")

axes[5].plot(df_x_sub["DOY"], df_x_sub["flux"], color='red')
axes[5].set_ylabel("X-ray \n[W/$m^{2}$]")

axes[2].plot(df_e_sub["DOY"], df_e_sub["flux"], color='red')
axes[2].set_ylabel("Electron \n[cm$^2$ s sr]")

axes[3].plot(df_p_sub["DOY"], df_p_sub["flux"], color='red')
axes[3].set_ylabel("Proton \n[cm$^2$ s sr]")

axes[4].plot(df_m_sub["DOY"], df_m_sub["flux"], color='red')
axes[4].set_ylabel("Mag \n[nT]")
axes[5].set_xlabel("Day of Year")

for i in [2,3,5]:
    axes[i].set_yscale("log")

for i in range(6):
    axes[i].set_xlim([days,daye])
    
fig.tight_layout()
plt.savefig(f"anomaly_{year}_1.png",dpi=600)
plt.show()

# %%
days, daye = 175, 178   

df_his = df[(df["DOY"] >= days) & (df["DOY"] < daye)]
df_s_sub = df_s[(df_s["DOY"] >= days) & (df_s["DOY"] < daye)]
df_x_sub = df_x[(df_x["DOY"] >= days) & (df_x["DOY"] < daye)]
df_e_sub = df_e[(df_e["DOY"] >= days) & (df_e["DOY"] < daye)]
df_p_sub = df_p[(df_p["DOY"] >= days) & (df_p["DOY"] < daye)]
df_m_sub = df_m[(df_m["DOY"] >= days) & (df_m["DOY"] < daye)]


fig, axes = plt.subplots(
    nrows=6, ncols=1,
    figsize=(5, 6),
    sharex=True,
    gridspec_kw={"hspace": 0} 
)




for ax in axes[:-1]:
    ax.tick_params(axis="x", which="both",
                   bottom=False, top=False, labelbottom=False)


axes[0].set_title(f"{year}")
axes[0].scatter(df_his["DOY"], df_his["Count"], s=2)
axes[0].set_ylabel("Dark count")

axes[1].plot(df_s_sub["DOY"], df_s_sub["SYM-H"], color='red')   
axes[1].set_ylabel("SYM-H \n[nT]")

axes[5].plot(df_x_sub["DOY"], df_x_sub["flux"], color='red')
axes[5].set_ylabel("X-ray \n[W/$m^{2}$]")

axes[2].plot(df_e_sub["DOY"], df_e_sub["flux"], color='red')
axes[2].set_ylabel("Electron \n[cm$^2$ s sr]")

axes[3].plot(df_p_sub["DOY"], df_p_sub["flux"], color='red')
axes[3].set_ylabel("Proton \n[cm$^2$ s sr]")

axes[4].plot(df_m_sub["DOY"], df_m_sub["flux"], color='red')
axes[4].set_ylabel("Mag \n[nT]")
axes[5].set_xlabel("Day of Year")

for i in [2,3,5]:
    axes[i].set_yscale("log")

for i in range(6):
    axes[i].set_xlim([days,daye])
    
fig.tight_layout()
plt.savefig(f"anomaly_{year}_2.png",dpi=600)
plt.show()
